# %%
# importing libraries

# %% [markdown]
# # prediction of car selling price

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#fetch data

# %%
car= pd.read_csv('car data.csv')

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
# to check total no of row and column

# %%
car.shape
# Out:
# (301, 9)

# %%
# checking top 5 row

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
# chaecking bottom 5 row

# %%
car.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
# checking the null values

# %%
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# drop irrelevant col car_name bcz selling price is not depend upon car name

# %%
car.drop('Car_Name',axis=1)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
car_data=car.drop('Present_Price',axis=1)

# %%
car_data.drop('Car_Name',axis=1)
# Out:
#      Year  Selling_Price  Kms_Driven Fuel_Type Seller_Type Transmission  Owner
# 0    2014           3.35       27000    Petrol      Dealer       Manual      0
# 1    2013           4.75       43000    Diesel      Dealer       Manual      0
# 2    2017           7.25        6900    Petrol      Dealer       Manual      0
# 3    2011           2.85        5200    Petrol      Dealer       Manual      0
# 4    2014           4.60       42450    Diesel      Dealer       Manual      0
# ..    ...            ...         ...       ...         ...          ...    ...
# 296  2016           9.50       33988    Diesel      Dealer       Manual      0
# 297  2015           4.00       60000    Petrol      Dealer       Manual      0
# 298  2009           3.35       87934    Petrol      Dealer       Manual      0
# 299  2017          11.50        9000    Diesel      Dealer       Manual      0
# 300  2016           5.30        5464    Petrol      Dealer       Manual      0
#
# [301 rows x 7 columns]

# %% [markdown]
# # finding the unique value

# %%
car_data['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
car_data['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
car_data['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %% [markdown]
# # endcoding unique value from feature

# %%
car_data['Fuel_Type']=car_data['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':2})

# %%
car_data['Seller_Type']=car_data['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
car_data['Transmission']=car_data['Transmission'].map({'Manual':0,'Automatic':1})

# %%
car_data
# Out:
#     Car_Name  Year  Selling_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0       ritz  2014           3.35       27000          0            0
# 1        sx4  2013           4.75       43000          1            0
# 2       ciaz  2017           7.25        6900          0            0
# 3    wagon r  2011           2.85        5200          0            0
# 4      swift  2014           4.60       42450          1            0
# ..       ...   ...            ...         ...        ...          ...
# 296     city  2016           9.50       33988          1            0
# 297     brio  2015           4.00       60000          0            0
# 298     city  2009           3.35       87934          0            0
# 299     city  2017          11.50        9000          1            0
# 300     brio  2016           5.30        5464          0            0
#
#      Transmission  Owner
# 0               0      0
# 1               0      0
# 2               0      0
# ...

# %%
data=car_data.drop('Car_Name',axis=1)

# %%
data
# Out:
#      Year  Selling_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           3.35       27000          0            0             0
# 1    2013           4.75       43000          1            0             0
# 2    2017           7.25        6900          0            0             0
# 3    2011           2.85        5200          0            0             0
# 4    2014           4.60       42450          1            0             0
# ..    ...            ...         ...        ...          ...           ...
# 296  2016           9.50       33988          1            0             0
# 297  2015           4.00       60000          0            0             0
# 298  2009           3.35       87934          0            0             0
# 299  2017          11.50        9000          1            0             0
# 300  2016           5.30        5464          0            0             0
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
# feature encoding successfully done

# %%
# splitting feature and target feature

# %%
x=data[['Year','Kms_Driven','Fuel_Type','Seller_Type','Transmission','Owner']]

# %%
x
# Out:
#      Year  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 0    2014       27000          0            0             0      0
# 1    2013       43000          1            0             0      0
# 2    2017        6900          0            0             0      0
# 3    2011        5200          0            0             0      0
# 4    2014       42450          1            0             0      0
# ..    ...         ...        ...          ...           ...    ...
# 296  2016       33988          1            0             0      0
# 297  2015       60000          0            0             0      0
# 298  2009       87934          0            0             0      0
# 299  2017        9000          1            0             0      0
# 300  2016        5464          0            0             0      0
#
# [301 rows x 6 columns]

# %%
y=data['Selling_Price']

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
# import train_test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test= train_test_split(x,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#      Year  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 185  2008        1900          0            1             1      0
# 72   2013       56001          0            0             0      0
# 15   2016       43000          1            0             0      0
# 10   2017        2135          0            0             0      0
# 196  2008      500000          0            1             1      0
# ..    ...         ...        ...          ...           ...    ...
# 188  2013       18000          0            1             0      0
# 71   2011       45000          1            0             0      0
# 106  2014       16500          0            1             0      1
# 270  2011       69341          0            0             0      0
# 102  2017        4000          0            1             0      0
#
# [210 rows x 6 columns]

# %%
data.shape
# Out:
# (301, 7)

# %%
X_train.shape
# Out:
# (210, 6)

# %%
X_test.shape
# Out:
# (91, 6)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm= LinearRegression()

# %%
model = lm.fit(X_train,Y_train)

# %%
model
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_train)

# %%
model.score(X_test,Y_test)
# Out:
# 0.6484936596059339

# %%
model.coef_
# Out:
# array([ 2.75978065e-01, -3.96694306e-07,  3.97309406e+00, -4.12946540e+00,
#         4.24812368e+00, -2.55428705e-01])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_pred,Y_train)
# Out:
# 0.013025408675861883
